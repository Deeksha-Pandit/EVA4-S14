# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha-Pandit/EVA4-S14/blob/master/DepthModel_Trial1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Deeksha-Pandit/EVA4-S14.git
# Out:
# fatal: destination path 'EVA4-S14' already exists and is not an empty directory.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./EVA4-S14/nyu.h5
# Out:
# --2020-05-03 13:42:42--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.109.251
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.109.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./EVA4-S14/nyu.h5’
#
# ./EVA4-S14/nyu.h5   100%[===================>] 164.89M  30.4MB/s    in 6.2s
#
# 2020-05-03 13:42:49 (26.7 MB/s) - ‘./EVA4-S14/nyu.h5’ saved [172897376/172897376]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
import os
folder = '/content/gdrive/My Drive/Mask_Rcnn/'
sys.path.append(folder)
for items in os.listdir(folder):
   print(items)
# Out:
# Fg-Bg-Noopur2
# Fg-Bg-Mask-Noopur2
# Fg-Bg-Deeksha
# Fg-Bg-Mask-Deeksha
# Background
# Foreground
# Mask
# .ipynb_checkpoints
# Fg-Bg-Mask
# Fg-Bg-Srini
# Fg-Bg-Mask-Srini
# Mask-Srini
# Foreground-Srini
# Foreground-Deeksha
# Mask-Deeksha
# Fg-Bg
# Fg-Bg-Noopur
# Fg-Bg-Mask-Noopur
# Fg-Bg-Deeksha2
# Fg-Bg-Mask-Deeksha2

# %%
# !cd EVA4-S14; python test.py --input "/content/gdrive/My Drive/Mask_Rcnn/Fg-Bg-Deeksha/fg-bg38680[1-9].jpg" --start 386801 --end 386809
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (9) images of size (224, 224, 3).
# (112, 112, 3)
# (112, 112)
# (112, 112)
# 386802
# (112, 112)
# (112, 112)
# 386803
# (112, 112)
# (112, 112)
# 386804
# (112, 112)
# (112, 112)
# 386805
# (112, 112)
# (112, 112)
# 386806
# (112, 112)
# (112, 112)
# 386807
# (112, 112)
# (112, 112)
# 386808
# (112, 112)
# (112, 112)
# 386809
# done

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(10,10))
#for i in range(386802,386809):
a = io.imread('./EVA4-S14/test386803.jpg')
plt.imshow( io.imread('./EVA4-S14/test386803.jpg') )
a.shape
# Out:
# (224, 224, 3)
