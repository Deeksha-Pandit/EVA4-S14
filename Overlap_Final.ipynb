# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeksha-Pandit/EVA4-S14/blob/master/Overlap_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %%
# !mkdir Overlay5

# %cd Overlay5
# !mkdir Fg-Bg
# !mkdir Fg-Bg-Mask
# Out:
# /content/Overlay5

# %%
# %cd ..
# Out:
# /content

# %%
path = '/content/gdrive/My Drive/Mask_Rcnn/'
start =320001 # -----------------------You should choose your numbers----------------------------------
black = np.zeros((224,224))



for i in range(1,101): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{path}living_room_224_224/bg{str(i)}.jpg')

    for j in  range(81,101): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{path}Deeksha/Foreground/fg{str(j)}.png')
      mask = Image.open(f'{path}Deeksha/Foreground-Mask/mask{str(j)}.png').convert('1')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 120)
        r2 = random.randint(1, 120)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='1')
        black_img2 = Image.fromarray(black,mode='1')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        

        bg1.paste(fg1, (r1,r2),fg1)
        bg2.paste(flipfg,(r1,r2),flipfg)
        black_img1.paste(m1,(r1,r2), m1)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"/content/Overlay5/Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder-------------
        black_img1.save(f"/content/Overlay5/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg") #-------------Create Different Path folder----

        start+=1

        bg2.save(f"/content/Overlay5/Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder---------------
        black_img2.save(f"/content/Overlay5/Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg")#------------Create Different folder-----------

        start+=1
        print(start)
# Out:
# Streaming output truncated to the last 5000 lines.
# 390005
# 390007
# 390009
# 390011
# 390013
# 390015
# 390017
# 390019
# 390021
# 390023
# 390025
# 390027
# 390029
# 390031
# 390033
# 390035
# 390037
# 390039
# 390041
# 390043
# 390045
# 390047
# 390049
# 390051
# 390053
# 390055
# 390057
# 390059
# 390061
# 390063
# 390065
# 390067
# 390069
# 390071
# 390073
# 390075
# 390077
# 390079
# 390081
# 390083
# 390085
# 390087
# 390089
# 390091
# 390093
# 390095
# 390097
# 390099
# 390101
# 390103
# 390105
# 390107
# 390109
# 390111
# 390113
# 390115
# 390117
# 390119
# 390121
# 390123
# 390125
# 390127
# 390129
# 390131
# 390133
# 390135
# 390137
# 390139
# 390141
# 390143
# 390145
# 390147
# 390149
# 390151
# 390153
# 390155
# 390157
# 390159
# 390161
# 390163
# 390165
# 390167
# 390169
# 390171
# 390173
# 390175
# 390177
# 390179
# 390181
# 390183
# 390185
# 390187
# 390189
# 390191
# 390193
# 390195
# 390197
# 390199
# 390201
# 390203
# 390205
# 390207
# 390209
# 390211
# 390213
# ...

# %%
# !pwd
# Out:
# /content

# %%
#Export Zip file
from zipfile import ZipFile 
import zipfile
import os 
  
def get_all_file_paths(directory): 
  
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath) 
  
    # returning all file paths 
    return file_paths         
  
def main(): 
    # path to folder which needs to be zipped 
    directory = 'Overlay5'
  
    # calling function to get all file paths in the directory 
    file_paths = get_all_file_paths(directory) 
  
    # printing the list of all files to be zipped 
    print('Following files will be zipped:') 
    for file_name in file_paths: 
        print(file_name) 
  
    # writing files to a zipfile 
    with ZipFile('/content/gdrive/My Drive/Mask_Rcnn/Deeksha/data_Part5','a', compression = zipfile.ZIP_DEFLATED) as zip: 
        # writing each file one by one 
        for file in file_paths: 
            zip.write(file) 
  
    print('All files zipped successfully!')         
  
  

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Overlay5/Fg-Bg/fg-bg364711.jpg
# Overlay5/Fg-Bg/fg-bg347292.jpg
# Overlay5/Fg-Bg/fg-bg344236.jpg
# Overlay5/Fg-Bg/fg-bg337952.jpg
# Overlay5/Fg-Bg/fg-bg340181.jpg
# Overlay5/Fg-Bg/fg-bg394123.jpg
# Overlay5/Fg-Bg/fg-bg327373.jpg
# Overlay5/Fg-Bg/fg-bg379827.jpg
# Overlay5/Fg-Bg/fg-bg355291.jpg
# Overlay5/Fg-Bg/fg-bg378397.jpg
# Overlay5/Fg-Bg/fg-bg329617.jpg
# Overlay5/Fg-Bg/fg-bg321552.jpg
# Overlay5/Fg-Bg/fg-bg386710.jpg
# Overlay5/Fg-Bg/fg-bg354791.jpg
# Overlay5/Fg-Bg/fg-bg339554.jpg
# Overlay5/Fg-Bg/fg-bg326646.jpg
# Overlay5/Fg-Bg/fg-bg375685.jpg
# Overlay5/Fg-Bg/fg-bg391972.jpg
# Overlay5/Fg-Bg/fg-bg373315.jpg
# Overlay5/Fg-Bg/fg-bg331708.jpg
# Overlay5/Fg-Bg/fg-bg386980.jpg
# Overlay5/Fg-Bg/fg-bg399716.jpg
# Overlay5/Fg-Bg/fg-bg386664.jpg
# Overlay5/Fg-Bg/fg-bg388723.jpg
# Overlay5/Fg-Bg/fg-bg367190.jpg
# Overlay5/Fg-Bg/fg-bg338893.jpg
# Overlay5/Fg-Bg/fg-bg362998.jpg
# Overlay5/Fg-Bg/fg-bg352171.jpg
# ...

# %%
# To extract a  file, this is for depth images. After zipping. Only to read images

#To import zip file
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "/content/gdrive/My Drive/Mask_Rcnn/Deeksha/data_Part5"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files now...') 
    zip.extractall() 
    print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
# !ls
# Out:
# gdrive	Overlay5  sample_data

# %%
# !ls Overlay5/Fg-Bg | wc - l
# Out:
#   80000   80000 1280000 -
# wc: l: No such file or directory
#   80000   80000 1280000 total

# %%
# !ls Overlay5/Fg-Bg-Mask | wc -l
# Out:
# 80000
